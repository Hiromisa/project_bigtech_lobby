# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
pd.set_option("display.max_rows", 150)
# Out:
# /Users/hiromi/.pyenv/versions/3.8.10/lib/python3.8/site-packages/pandas/compat/__init__.py:97: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# # Scraping

# %% [markdown]
# ## 1. Amazon

# %%
url1 = 'https://lda.senate.gov/filings/public/filing/search/?registrant=amazon&registrant_country=&registrant_ppb_country=&client=&client_state=&client_country=&client_ppb_country=&lobbyist=&lobbyist_covered_position=&lobbyist_conviction_disclosure=&lobbyist_conviction_date_range_from=&lobbyist_conviction_date_range_to=&report_period=&report_year=&report_dt_posted_from=&report_dt_posted_to=&report_amount_reported_min=&report_amount_reported_max=&report_issue_area_description=&affiliated_organization=&affiliated_organization_country=&foreign_entity=&foreign_entity_country=&foreign_entity_ppb_country=&foreign_entity_ownership_percentage_min=&foreign_entity_ownership_percentage_max=&search=search#js_searchFormTitle'

# %%
#use easy scraping way io.html.read_html()
df1 = pd.io.html.read_html(url1)
df_amazon = df1[0]
df_amazon = df_amazon.sort_values(by = 'Filing Year', ascending=False)
df_amazon['AmountReported'] = df_amazon['AmountReported'].str.replace('$', '', regex=True).str.replace(',','').astype(float)
df_amazon['season'] = df_amazon['Filing Year'].astype(str)  + ' ' +  df_amazon['Report Type']

# %%
# get the link info 
response = requests.get(url1)
doc = BeautifulSoup(response.text, 'html.parser')
lobbylists = doc.select('.tr--clickable')
amazon_lobby_list = []
for lobbylist in lobbylists:
    dict = {}
    dict['Posted'] = lobbylist.select_one('.col-w--sm').text.strip()
    dict['link'] = 'https://lda.senate.gov/' + lobbylist.select_one('.js_clickableRowTarget')['href']    
    amazon_lobby_list.append(dict)

# %%
#DataFrame of PDF link to Amazon's lobby
df_amazon_link = pd.DataFrame(amazon_lobby_list)

# %%
print(df_amazon.shape)
print(df_amazon_link.shape)
# Out:
# (79, 7)
# (79, 2)

# %%
#merge 2 DataFrame
df_amazon = df_amazon.merge(df_amazon_link, how='left', on='Posted')

# %%
#Pick important columns
df_Amazon = df_amazon.rename(columns={'AmountReported' : 'amazon_lobby', 'link': 'amazon_link'})
df_Amazon = df_Amazon[['Registrant Name', 'season','amazon_lobby','amazon_link']]

# %%
df_Amazon.head(2)
# Out:
#            Registrant Name                     season  amazon_lobby  \
# 0  AMAZON.COM SERVICES LLC  2021 2nd Quarter - Report     4860000.0
# 1  AMAZON.COM SERVICES LLC  2021 1st Quarter - Report     4800000.0
#
#                                          amazon_link
# 0  https://lda.senate.gov//filings/public/filing/...
# 1  https://lda.senate.gov//filings/public/filing/...

# %% [markdown]
# ## 2. Facebook

# %%
url2 = 'https://lda.senate.gov/filings/public/filing/search/?registrant=facebook&registrant_country=&registrant_ppb_country=&client=&client_state=&client_country=&client_ppb_country=&lobbyist=&lobbyist_covered_position=&lobbyist_conviction_disclosure=&lobbyist_conviction_date_range_from=&lobbyist_conviction_date_range_to=&report_period=&report_year=&report_dt_posted_from=&report_dt_posted_to=&report_amount_reported_min=&report_amount_reported_max=&report_issue_area_description=&affiliated_organization=&affiliated_organization_country=&foreign_entity=&foreign_entity_country=&foreign_entity_ppb_country=&foreign_entity_ownership_percentage_min=&foreign_entity_ownership_percentage_max=&search=search#js_searchFormTitle'

# %%
#use easy scraping way io.html.read_html()
df2 = pd.io.html.read_html(url2)
df_facebook = df2[0]
df_facebook = df_facebook.sort_values(by = 'Filing Year', ascending=False)
df_facebook['AmountReported'] = df_facebook['AmountReported'].str.replace('$', '', regex=True).str.replace(',','').astype(float)
df_facebook['season'] = df_facebook['Filing Year'].astype(str)  + ' ' +  df_facebook['Report Type']

# %%
# get the link info 
response = requests.get(url2)
doc = BeautifulSoup(response.text, 'html.parser')
lobbylists = doc.select('.tr--clickable')
facebook_lobby_list = []
for lobbylist in lobbylists:
    dict = {}
    dict['Posted'] = lobbylist.select_one('.col-w--sm').text.strip()
    dict['link'] = 'https://lda.senate.gov/' + lobbylist.select_one('.js_clickableRowTarget')['href']    
    facebook_lobby_list.append(dict)

# %%
#DataFrame of PDF link to FB's lobby
df_facebook_link = pd.DataFrame(facebook_lobby_list)

# %%
print(df_facebook.shape)
print(df_facebook_link.shape)
# Out:
# (53, 7)
# (53, 2)

# %%
#merge 2 DataFrame
df_facebook = df_facebook.merge(df_facebook_link, how='left', on='Posted')

# %%
#Pick important columns
df_Facebook = df_facebook.rename(columns={'AmountReported' : 'facebook_lobby', 'link': 'facebook_link'})
df_Facebook = df_Facebook[['Registrant Name', 'season','facebook_lobby','facebook_link']]

# %%
df_Facebook.head()
# Out:
#                            Registrant Name                        season  \
# 0  FACEBOOK, INC. AND VARIOUS SUBSIDIARIES     2021 2nd Quarter - Report
# 1  FACEBOOK, INC. AND VARIOUS SUBSIDIARIES     2021 1st Quarter - Report
# 2  FACEBOOK, INC. AND VARIOUS SUBSIDIARIES     2020 1st Quarter - Report
# 3  FACEBOOK, INC. AND VARIOUS SUBSIDIARIES     2020 4th Quarter - Report
# 4  FACEBOOK, INC. AND VARIOUS SUBSIDIARIES  2020 3rd Quarter - Amendment
#
#    facebook_lobby                                      facebook_link
# 0       4770000.0  https://lda.senate.gov//filings/public/filing/...
# 1       4790000.0  https://lda.senate.gov//filings/public/filing/...
# 2       5260000.0  https://lda.senate.gov//filings/public/filing/...
# 3       4690000.0  https://lda.senate.gov//filings/public/filing/...
# 4       4900000.0  https://lda.senate.gov//filings/public/filing/...

# %% [markdown]
# ## 3. Google

# %%
url3 = 'https://lda.senate.gov/filings/public/filing/search/?registrant=google&registrant_country=&registrant_ppb_country=&client=&client_state=&client_country=&client_ppb_country=&lobbyist=&lobbyist_covered_position=&lobbyist_conviction_disclosure=&lobbyist_conviction_date_range_from=&lobbyist_conviction_date_range_to=&report_period=&report_year=&report_dt_posted_from=&report_dt_posted_to=&report_amount_reported_min=&report_amount_reported_max=&report_issue_area_description=&affiliated_organization=&affiliated_organization_country=&foreign_entity=&foreign_entity_country=&foreign_entity_ppb_country=&foreign_entity_ownership_percentage_min=&foreign_entity_ownership_percentage_max=&search=search#js_searchFormTitle'

# %%
#use easy scraping way io.html.read_html()
df3 = pd.io.html.read_html(url3)
df_google = df3[0]
df_google = df_google.sort_values(by = 'Filing Year', ascending=False)
df_google['AmountReported'] = df_google['AmountReported'].str.replace('$', '', regex=True).str.replace(',','').astype(float)
df_google['season'] = df_google['Filing Year'].astype(str)  + ' ' +  df_google['Report Type']

# %%
# get the link info 
response = requests.get(url3)
doc = BeautifulSoup(response.text, 'html.parser')
lobbylists = doc.select('.tr--clickable')
google_lobby_list = []
for lobbylist in lobbylists:
    dict = {}
    dict['Posted'] = lobbylist.select_one('.col-w--sm').text.strip()
    dict['link'] = 'https://lda.senate.gov/' + lobbylist.select_one('.js_clickableRowTarget')['href']    
    google_lobby_list.append(dict)

# %%
#DataFrame of PDF link to google's lobby
df_google_link = pd.DataFrame(google_lobby_list)

# %%
print(df_google.shape)
print(df_google_link.shape)
# Out:
# (63, 7)
# (63, 2)

# %%
#merge 2 DataFrame
df_google = df_google.merge(df_google_link, how='left', on='Posted')

# %%
#Pick important columns
df_Google = df_google.rename(columns={'AmountReported' : 'google_lobby', 'link': 'google_link'})
df_Google = df_Google[['Registrant Name', 'season','google_lobby','google_link']]

# %%
df_Google.head()
# Out:
#               Registrant Name                     season  google_lobby  \
# 0  GOOGLE CLIENT SERVICES LLC  2021 2nd Quarter - Report     2090000.0
# 1  GOOGLE CLIENT SERVICES LLC  2021 1st Quarter - Report     2690000.0
# 2  GOOGLE CLIENT SERVICES LLC  2020 4th Quarter - Report     2110000.0
# 3  GOOGLE CLIENT SERVICES LLC  2020 3rd Quarter - Report     1930000.0
# 4  GOOGLE CLIENT SERVICES LLC  2020 2nd Quarter - Report     1690000.0
#
#                                          google_link
# 0  https://lda.senate.gov//filings/public/filing/...
# 1  https://lda.senate.gov//filings/public/filing/...
# 2  https://lda.senate.gov//filings/public/filing/...
# 3  https://lda.senate.gov//filings/public/filing/...
# 4  https://lda.senate.gov//filings/public/filing/...

# %% [markdown]
# ### 4. Apple

# %%
url4 = 'https://lda.senate.gov/filings/public/filing/search/?registrant=apple+inc&registrant_country=&registrant_ppb_country=&client=&client_state=&client_country=&client_ppb_country=&lobbyist=&lobbyist_covered_position=&lobbyist_conviction_disclosure=&lobbyist_conviction_date_range_from=&lobbyist_conviction_date_range_to=&report_period=&report_year=&report_dt_posted_from=&report_dt_posted_to=&report_amount_reported_min=&report_amount_reported_max=&report_issue_area_description=&affiliated_organization=&affiliated_organization_country=&foreign_entity=&foreign_entity_country=&foreign_entity_ppb_country=&foreign_entity_ownership_percentage_min=&foreign_entity_ownership_percentage_max=&search=search#js_searchFormTitle'

# %%
#use easy scraping way io.html.read_html()
df4 = pd.io.html.read_html(url4)
df_apple = df4[0]
df_apple = df_apple.sort_values(by = 'Filing Year', ascending=False)
df_apple['AmountReported'] = df_apple['AmountReported'].str.replace('$', '', regex=True).str.replace(',','').astype(float)
df_apple['season'] = df_apple['Filing Year'].astype(str)  + ' ' +  df_apple['Report Type']

# %%
# get the link info 
response = requests.get(url4)
doc = BeautifulSoup(response.text, 'html.parser')
lobbylists = doc.select('.tr--clickable')
apple_lobby_list = []
for lobbylist in lobbylists:
    dict = {}
    dict['Posted'] = lobbylist.select_one('.col-w--sm').text.strip()
    dict['link'] = 'https://lda.senate.gov/' + lobbylist.select_one('.js_clickableRowTarget')['href']    
    apple_lobby_list.append(dict)

# %%
#DataFrame of PDF link to google's lobby
df_apple_link = pd.DataFrame(apple_lobby_list)

# %%
print(df_apple.shape)
print(df_apple_link.shape)
# Out:
# (89, 7)
# (89, 2)

# %%
#merge 2 DataFrame
df_apple = df_apple.merge(df_apple_link, how='left', on='Posted')

# %%
#Pick important columns
df_Apple = df_apple.rename(columns={'AmountReported' : 'apple_lobby', 'link': 'apple_link'})
df_Apple = df_Apple[['Registrant Name', 'season','apple_lobby','apple_link']]

# %%
df_Apple.head()
# Out:
#   Registrant Name                        season  apple_lobby  \
# 0      APPLE INC.     2021 1st Quarter - Report    1460000.0
# 1      APPLE INC.     2021 2nd Quarter - Report    1640000.0
# 2      APPLE INC.  2020 3rd Quarter - Amendment    1560000.0
# 3      APPLE INC.     2020 3rd Quarter - Report    1560000.0
# 4      APPLE INC.     2020 4th Quarter - Report    1450000.0
#
#                                           apple_link
# 0  https://lda.senate.gov//filings/public/filing/...
# 1  https://lda.senate.gov//filings/public/filing/...
# 2  https://lda.senate.gov//filings/public/filing/...
# 3  https://lda.senate.gov//filings/public/filing/...
# 4  https://lda.senate.gov//filings/public/filing/...

# %% [markdown]
# ## 5. Microsoft

# %%
url5 = 'https://lda.senate.gov/filings/public/filing/search/?registrant=microsoft&registrant_country=&registrant_ppb_country=&client=&client_state=&client_country=&client_ppb_country=&lobbyist=&lobbyist_covered_position=&lobbyist_conviction_disclosure=&lobbyist_conviction_date_range_from=&lobbyist_conviction_date_range_to=&report_period=&report_year=&report_dt_posted_from=&report_dt_posted_to=&report_amount_reported_min=&report_amount_reported_max=&report_issue_area_description=&affiliated_organization=&affiliated_organization_country=&foreign_entity=&foreign_entity_country=&foreign_entity_ppb_country=&foreign_entity_ownership_percentage_min=&foreign_entity_ownership_percentage_max=&search=search#js_searchFormTitle'

# %%
#use easy scraping way io.html.read_html()
df5 = pd.io.html.read_html(url5)
df_microsoft = df5[0]
df_microsoft = df_microsoft.sort_values(by = 'Filing Year', ascending=False)
df_microsoft['AmountReported'] = df_microsoft['AmountReported'].str.replace('$', '', regex=True).str.replace(',','').astype(float)
df_microsoft['season'] = df_microsoft['Filing Year'].astype(str)  + ' ' +  df_microsoft['Report Type']

# %%
# get the link info 
response = requests.get(url5)
doc = BeautifulSoup(response.text, 'html.parser')
lobbylists = doc.select('.tr--clickable')
msft_lobby_list = []
for lobbylist in lobbylists:
    dict = {}
    dict['Posted'] = lobbylist.select_one('.col-w--sm').text.strip()
    dict['link'] = 'https://lda.senate.gov/' + lobbylist.select_one('.js_clickableRowTarget')['href']    
    msft_lobby_list.append(dict)

# %%
#DataFrame of PDF link to google's lobby
df_microsoft_link = pd.DataFrame(msft_lobby_list)

# %%
print(df_microsoft.shape)
print(df_microsoft_link.shape)
# Out:
# (76, 7)
# (76, 2)

# %%
#merge 2 DataFrame
df_microsoft = df_microsoft.merge(df_microsoft_link, how='left', on='Posted')

# %%
#Pick important columns
df_Microsoft = df_microsoft.rename(columns={'AmountReported' : 'microsoft_lobby', 'link': 'microsoft_link'})
df_Microsoft = df_Microsoft[['Registrant Name', 'season','microsoft_lobby','microsoft_link']]

# %%
df_Microsoft.head()
# Out:
#          Registrant Name                     season  microsoft_lobby  \
# 0  MICROSOFT CORPORATION  2021 2nd Quarter - Report        2470000.0
# 1  MICROSOFT CORPORATION  2021 1st Quarter - Report        2590000.0
# 2  MICROSOFT CORPORATION  2020 4th Quarter - Report        2190000.0
# 3  MICROSOFT CORPORATION  2020 3rd Quarter - Report        1880000.0
# 4  MICROSOFT CORPORATION  2020 2nd Quarter - Report        2910000.0
#
#                                       microsoft_link
# 0  https://lda.senate.gov//filings/public/filing/...
# 1  https://lda.senate.gov//filings/public/filing/...
# 2  https://lda.senate.gov//filings/public/filing/...
# 3  https://lda.senate.gov//filings/public/filing/...
# 4  https://lda.senate.gov//filings/public/filing/...

# %% [markdown]
# ## 6. Bigtech (combined table)

# %%
df_bigtech = df_Amazon.merge(df_Facebook, on = ['season'], how = 'outer')\
    .merge(df_Google, on = ['season'], how = 'outer')\
    .merge(df_Apple, on = ['season'], how = 'outer')\
    .merge(df_Microsoft, on = ['season'], how = 'outer')

# %%
df_bigtech.shape
# Out:
# (148, 16)

# %%
# df_bigtech.columns

# %%
df_Bigtech = df_bigtech[['season', 'amazon_lobby','facebook_lobby','google_lobby','apple_lobby','microsoft_lobby', \
                        'amazon_link','facebook_link','google_link','apple_link','microsoft_link']]

# %%
df_Bigtech = df_Bigtech.sort_values(by='season', ascending=False).fillna(0)

# %%
df_Bigtech['year'] = df_Bigtech['season'].str[:4].astype(int)

# %%
df_Bigtech = df_Bigtech[['season','year','amazon_lobby','facebook_lobby','google_lobby','apple_lobby','microsoft_lobby', \
                        'amazon_link','facebook_link','google_link','apple_link','microsoft_link']].reset_index(drop = True)

# %%
# df_Bigtech.info()

# %%
df_Bigtech
# Out:
#                             season  year  amazon_lobby  facebook_lobby  \
# 0        2021 2nd Quarter - Report  2021     4860000.0       4770000.0
# 1        2021 1st Quarter - Report  2021     4800000.0       4790000.0
# 2        2020 4th Quarter - Report  2020     4740000.0       4690000.0
# 3        2020 3rd Quarter - Report  2020     4410000.0       4900000.0
# 4     2020 3rd Quarter - Amendment  2020           0.0       4900000.0
# 5        2020 2nd Quarter - Report  2020     4380000.0       4830000.0
# 6        2020 1st Quarter - Report  2020     4330000.0       5260000.0
# 7        2019 4th Quarter - Report  2019     4210000.0       4430000.0
# 8     2019 4th Quarter - Amendment  2019           0.0             0.0
# 9        2019 3rd Quarter - Report  2019     4030000.0       4770000.0
# 10       2019 2nd Quarter - Report  2019     4010000.0       4110000.0
# 11       2019 1st Quarter - Report  2019     3890000.0       3400000.0
# 12       2018 4th Quarter - Report  2018     3710000.0       2830000.0
# 39   https://lda.senate.gov//filings/public/filing/...
# 40   https://lda.senate.gov//filings/public/filing/...
# 41   https://lda.senate.gov//filings/public/filing/...
# 42   https://lda.senate.gov//filings/public/filing/...
# 43   https://lda.senate.gov//filings/public/filing/...
# 44                                                   0
# 45   https://lda.senate.gov//filings/public/filing/...
# 46   https://lda.senate.gov//filings/public/filing/...
# 47   https://lda.senate.gov//filings/public/filing/...
# 48   https://lda.senate.gov//filings/public/filing/...
# 49   https://lda.senate.gov//filings/public/filing/...
# 50   https://lda.senate.gov//filings/public/filing/...
# 51   https://lda.senate.gov//filings/public/filing/...
# 52   https://lda.senate.gov//filings/public/filing/...
# 53   https://lda.senate.gov//filings/public/filing/...
# 54   https://lda.senate.gov//filings/public/filing/...
# 55   https://lda.senate.gov//filings/public/filing/...
# 56                                                   0
# 57   https://lda.senate.gov//filings/public/filing/...
# 58   https://lda.senate.gov//filings/public/filing/...
# 59   https://lda.senate.gov//filings/public/filing/...
# 60                                                   0
# 61   https://lda.senate.gov//filings/public/filing/...
# 62   https://lda.senate.gov//filings/public/filing/...
# 63   https://lda.senate.gov//filings/public/filing/...
# 64   https://lda.senate.gov//filings/public/filing/...
# 65                                                   0
# 66   https://lda.senate.gov//filings/public/filing/...
# 67                                                   0
# 68   https://lda.senate.gov//filings/public/filing/...
# 69                                                   0
# 70                                                   0
# 71                                                   0
# 72                                                   0
# 73                                                   0
# 74   https://lda.senate.gov//filings/public/filing/...
# 75                                                   0
# 76   https://lda.senate.gov//filings/public/filing/...
# 77   https://lda.senate.gov//filings/public/filing/...
# 78   https://lda.senate.gov//filings/public/filing/...
# 79   https://lda.senate.gov//filings/public/filing/...
# 80   https://lda.senate.gov//filings/public/filing/...
# 81   https://lda.senate.gov//filings/public/filing/...
# 82   https://lda.senate.gov//filings/public/filing/...
# 83                                                   0
# 84                                                   0
# 85   https://lda.senate.gov//filings/public/filing/...
# 86   https://lda.senate.gov//filings/public/filing/...
# 87   https://lda.senate.gov//filings/public/filing/...
# 88                                                   0
# 89   https://lda.senate.gov//filings/public/filing/...
# 90                                                   0
# 91   https://lda.senate.gov//filings/public/filing/...
# 92   https://lda.senate.gov//filings/public/filing/...
# 93   https://lda.senate.gov//filings/public/filing/...
# 94   https://lda.senate.gov//filings/public/filing/...
# 95   https://lda.senate.gov//filings/public/filing/...
# 96   https://lda.senate.gov//filings/public/filing/...
# 97   https://lda.senate.gov//filings/public/filing/...
# 98                                                   0
# 99   https://lda.senate.gov//filings/public/filing/...
# 100  https://lda.senate.gov//filings/public/filing/...
# 101  https://lda.senate.gov//filings/public/filing/...
# 102  https://lda.senate.gov//filings/public/filing/...
# 103  https://lda.senate.gov//filings/public/filing/...
# 104  https://lda.senate.gov//filings/public/filing/...
# 105  https://lda.senate.gov//filings/public/filing/...
# 106                                                  0
# 107  https://lda.senate.gov//filings/public/filing/...
# 108  https://lda.senate.gov//filings/public/filing/...
# 109  https://lda.senate.gov//filings/public/filing/...
# 110  https://lda.senate.gov//filings/public/filing/...
# 2    https://lda.senate.gov//filings/public/filing/...
# 3    https://lda.senate.gov//filings/public/filing/...
# 4                                                    0
# 5    https://lda.senate.gov//filings/public/filing/...
# 6    https://lda.senate.gov//filings/public/filing/...
# 7    https://lda.senate.gov//filings/public/filing/...
# 8                                                    0
# 9    https://lda.senate.gov//filings/public/filing/...
# 10   https://lda.senate.gov//filings/public/filing/...
# 11   https://lda.senate.gov//filings/public/filing/...
# 12   https://lda.senate.gov//filings/public/filing/...
# 13   https://lda.senate.gov//filings/public/filing/...
# 14   https://lda.senate.gov//filings/public/filing/...
# 15   https://lda.senate.gov//filings/public/filing/...
# 16   https://lda.senate.gov//filings/public/filing/...
# 17   https://lda.senate.gov//filings/public/filing/...
# 18                                                   0
# 19   https://lda.senate.gov//filings/public/filing/...
# 20   https://lda.senate.gov//filings/public/filing/...
# 21                                                   0
# 22   https://lda.senate.gov//filings/public/filing/...
# 23   https://lda.senate.gov//filings/public/filing/...
# 24   https://lda.senate.gov//filings/public/filing/...
# 25   https://lda.senate.gov//filings/public/filing/...
# 26   https://lda.senate.gov//filings/public/filing/...
# 27   https://lda.senate.gov//filings/public/filing/...
# 28                                                   0
# 29   https://lda.senate.gov//filings/public/filing/...
# 30   https://lda.senate.gov//filings/public/filing/...
# 31   https://lda.senate.gov//filings/public/filing/...
# 32   https://lda.senate.gov//filings/public/filing/...
# 33   https://lda.senate.gov//filings/public/filing/...
# 34   https://lda.senate.gov//filings/public/filing/...
# 35   https://lda.senate.gov//filings/public/filing/...
# 36   https://lda.senate.gov//filings/public/filing/...
# 37   https://lda.senate.gov//filings/public/filing/...
# 38   https://lda.senate.gov//filings/public/filing/...
# 39   https://lda.senate.gov//filings/public/filing/...
# 40   https://lda.senate.gov//filings/public/filing/...
# 41   https://lda.senate.gov//filings/public/filing/...
# 42   https://lda.senate.gov//filings/public/filing/...
# 43   https://lda.senate.gov//filings/public/filing/...
# 44                                                   0
# 45   https://lda.senate.gov//filings/public/filing/...
# 46                                                   0
# 47   https://lda.senate.gov//filings/public/filing/...
# 48   https://lda.senate.gov//filings/public/filing/...
# 49   https://lda.senate.gov//filings/public/filing/...
# 50   https://lda.senate.gov//filings/public/filing/...
# 51   https://lda.senate.gov//filings/public/filing/...
# 52   https://lda.senate.gov//filings/public/filing/...
# 53   https://lda.senate.gov//filings/public/filing/...
# 54   https://lda.senate.gov//filings/public/filing/...
# 55   https://lda.senate.gov//filings/public/filing/...
# 56                                                   0
# 57   https://lda.senate.gov//filings/public/filing/...
# 58   https://lda.senate.gov//filings/public/filing/...
# 59   https://lda.senate.gov//filings/public/filing/...
# 60                                                   0
# 61   https://lda.senate.gov//filings/public/filing/...
# 62   https://lda.senate.gov//filings/public/filing/...
# 63   https://lda.senate.gov//filings/public/filing/...
# 64   https://lda.senate.gov//filings/public/filing/...
# 65                                                   0
# 66   https://lda.senate.gov//filings/public/filing/...
# 67                                                   0
# 68   https://lda.senate.gov//filings/public/filing/...
# 69   https://lda.senate.gov//filings/public/filing/...
# 30   https://lda.senate.gov//filings/public/filing/...
# 31   https://lda.senate.gov//filings/public/filing/...
# 32                                                   0
# 33   https://lda.senate.gov//filings/public/filing/...
# 34   https://lda.senate.gov//filings/public/filing/...
# 35   https://lda.senate.gov//filings/public/filing/...
# 36                                                   0
# 37   https://lda.senate.gov//filings/public/filing/...
# 38   https://lda.senate.gov//filings/public/filing/...
# 39   https://lda.senate.gov//filings/public/filing/...
# 40   https://lda.senate.gov//filings/public/filing/...
# 41   https://lda.senate.gov//filings/public/filing/...
# 42   https://lda.senate.gov//filings/public/filing/...
# 43   https://lda.senate.gov//filings/public/filing/...
# 44                                                   0
# 45   https://lda.senate.gov//filings/public/filing/...
# 46                                                   0
# 47   https://lda.senate.gov//filings/public/filing/...
# 48   https://lda.senate.gov//filings/public/filing/...
# 49   https://lda.senate.gov//filings/public/filing/...
# 50   https://lda.senate.gov//filings/public/filing/...
# 51   https://lda.senate.gov//filings/public/filing/...
# 52   https://lda.senate.gov//filings/public/filing/...
# 53   https://lda.senate.gov//filings/public/filing/...
# 54   https://lda.senate.gov//filings/public/filing/...
# 55   https://lda.senate.gov//filings/public/filing/...
# 56                                                   0
# 57   https://lda.senate.gov//filings/public/filing/...
# 58   https://lda.senate.gov//filings/public/filing/...
# 59   https://lda.senate.gov//filings/public/filing/...
# 60                                                   0
# 61   https://lda.senate.gov//filings/public/filing/...
# 62   https://lda.senate.gov//filings/public/filing/...
# 63   https://lda.senate.gov//filings/public/filing/...
# 64   https://lda.senate.gov//filings/public/filing/...
# 65                                                   0
# 66   https://lda.senate.gov//filings/public/filing/...
# 67   https://lda.senate.gov//filings/public/filing/...
# 68   https://lda.senate.gov//filings/public/filing/...
# 69                                                   0
# 70                                                   0
# 71   https://lda.senate.gov//filings/public/filing/...
# 72   https://lda.senate.gov//filings/public/filing/...
# 73                                                   0
# 74   https://lda.senate.gov//filings/public/filing/...
# 75   https://lda.senate.gov//filings/public/filing/...
# 76   https://lda.senate.gov//filings/public/filing/...
# 77   https://lda.senate.gov//filings/public/filing/...
# 78   https://lda.senate.gov//filings/public/filing/...
# 79   https://lda.senate.gov//filings/public/filing/...
# 80   https://lda.senate.gov//filings/public/filing/...
# 81   https://lda.senate.gov//filings/public/filing/...
# 82   https://lda.senate.gov//filings/public/filing/...
# 83   https://lda.senate.gov//filings/public/filing/...
# 84   https://lda.senate.gov//filings/public/filing/...
# 85   https://lda.senate.gov//filings/public/filing/...
# 86   https://lda.senate.gov//filings/public/filing/...
# 87   https://lda.senate.gov//filings/public/filing/...
# 88                                                   0
# 89   https://lda.senate.gov//filings/public/filing/...
# 90   https://lda.senate.gov//filings/public/filing/...
# 91   https://lda.senate.gov//filings/public/filing/...
# 92   https://lda.senate.gov//filings/public/filing/...
# 93   https://lda.senate.gov//filings/public/filing/...
# 94   https://lda.senate.gov//filings/public/filing/...
# 95   https://lda.senate.gov//filings/public/filing/...
# 96   https://lda.senate.gov//filings/public/filing/...
# 97   https://lda.senate.gov//filings/public/filing/...
# 98                                                   0
# 99   https://lda.senate.gov//filings/public/filing/...
# 100                                                  0
# 101                                                  0
# 102                                                  0
# 103                                                  0
# 104                                                  0
# 105                                                  0
# 106  https://lda.senate.gov//filings/public/filing/...
# 107                                                  0
# 108                                                  0
# 109                                                  0
# 110                                                  0
# 111                                                  0
# 112                                                  0
# 113  https://lda.senate.gov//filings/public/filing/...
# 114  https://lda.senate.gov//filings/public/filing/...
# 115  https://lda.senate.gov//filings/public/filing/...
# 116  https://lda.senate.gov//filings/public/filing/...
# 117                                                  0
# 118                                                  0
# 119                                                  0
# 120                                                  0
# 121                                                  0
# 122                                                  0
# 123                                                  0
# 124                                                  0
# 125  https://lda.senate.gov//filings/public/filing/...
# 126                                                  0
# 127                                                  0
# 128                                                  0
# 129                                                  0
# 130                                                  0
# 131                                                  0
# 132                                                  0
# 133                                                  0
# 134                                                  0
# 135  https://lda.senate.gov//filings/public/filing/...
# 136  https://lda.senate.gov//filings/public/filing/...
# 137                                                  0
# 138                                                  0
# 139                                                  0
# 140                                                  0
# 141                                                  0
# 142                                                  0
# 143  https://lda.senate.gov//filings/public/filing/...
# 144  https://lda.senate.gov//filings/public/filing/...
# 145  https://lda.senate.gov//filings/public/filing/...
# 146  https://lda.senate.gov//filings/public/filing/...
# 147  https://lda.senate.gov//filings/public/filing/...
#
#                                         microsoft_link
# 0    https://lda.senate.gov//filings/public/filing/...
# 1    https://lda.senate.gov//filings/public/filing/...
# 2    https://lda.senate.gov//filings/public/filing/...
# 3    https://lda.senate.gov//filings/public/filing/...
# 4                                                    0
# 5    https://lda.senate.gov//filings/public/filing/...
# 6    https://lda.senate.gov//filings/public/filing/...
# 7    https://lda.senate.gov//filings/public/filing/...
# 8                                                    0
# 9    https://lda.senate.gov//filings/public/filing/...
# 10   https://lda.senate.gov//filings/public/filing/...
# 11   https://lda.senate.gov//filings/public/filing/...
# 12   https://lda.senate.gov//filings/public/filing/...
# 13   https://lda.senate.gov//filings/public/filing/...
# 14   https://lda.senate.gov//filings/public/filing/...
# 15                                                   0
# 16   https://lda.senate.gov//filings/public/filing/...
# 17   https://lda.senate.gov//filings/public/filing/...
# 18                                                   0
# 19   https://lda.senate.gov//filings/public/filing/...
# 20   https://lda.senate.gov//filings/public/filing/...
# 21                                                   0
# 22   https://lda.senate.gov//filings/public/filing/...
# 23   https://lda.senate.gov//filings/public/filing/...
# 24   https://lda.senate.gov//filings/public/filing/...
# 25   https://lda.senate.gov//filings/public/filing/...
# 26   https://lda.senate.gov//filings/public/filing/...
# 27   https://lda.senate.gov//filings/public/filing/...
# 28                                                   0
# 29   https://lda.senate.gov//filings/public/filing/...
# 30   https://lda.senate.gov//filings/public/filing/...
# 31   https://lda.senate.gov//filings/public/filing/...
# 32                                                   0
# 33   https://lda.senate.gov//filings/public/filing/...
# 34   https://lda.senate.gov//filings/public/filing/...
# 35   https://lda.senate.gov//filings/public/filing/...
# 36                                                   0
# 37   https://lda.senate.gov//filings/public/filing/...
# 38   https://lda.senate.gov//filings/public/filing/...
# 39   https://lda.senate.gov//filings/public/filing/...
# 40   https://lda.senate.gov//filings/public/filing/...
# 41   https://lda.senate.gov//filings/public/filing/...
# 42   https://lda.senate.gov//filings/public/filing/...
# 43   https://lda.senate.gov//filings/public/filing/...
# 44                                                   0
# 45   https://lda.senate.gov//filings/public/filing/...
# 46                                                   0
# 47   https://lda.senate.gov//filings/public/filing/...
# 48   https://lda.senate.gov//filings/public/filing/...
# 49   https://lda.senate.gov//filings/public/filing/...
# 50   https://lda.senate.gov//filings/public/filing/...
# 51   https://lda.senate.gov//filings/public/filing/...
# 52   https://lda.senate.gov//filings/public/filing/...
# 53   https://lda.senate.gov//filings/public/filing/...
# 54   https://lda.senate.gov//filings/public/filing/...
# 55   https://lda.senate.gov//filings/public/filing/...
# 56                                                   0
# 57   https://lda.senate.gov//filings/public/filing/...
# 58   https://lda.senate.gov//filings/public/filing/...
# 59   https://lda.senate.gov//filings/public/filing/...
# 60                                                   0
# 61   https://lda.senate.gov//filings/public/filing/...
# 62   https://lda.senate.gov//filings/public/filing/...
# 63   https://lda.senate.gov//filings/public/filing/...
# 64   https://lda.senate.gov//filings/public/filing/...
# 65   https://lda.senate.gov//filings/public/filing/...
# 66   https://lda.senate.gov//filings/public/filing/...
# 67   https://lda.senate.gov//filings/public/filing/...
# 68   https://lda.senate.gov//filings/public/filing/...
# 69                                                   0
# 70                                                   0
# 71                                                   0
# 72                                                   0
# 73                                                   0
# 74   https://lda.senate.gov//filings/public/filing/...
# 75                                                   0
# 76   https://lda.senate.gov//filings/public/filing/...
# 77   https://lda.senate.gov//filings/public/filing/...
# 78                                                   0
# 79                                                   0
# 80   https://lda.senate.gov//filings/public/filing/...
# 81   https://lda.senate.gov//filings/public/filing/...
# 82   https://lda.senate.gov//filings/public/filing/...
# 83                                                   0
# 84                                                   0
# 85   https://lda.senate.gov//filings/public/filing/...
# 86   https://lda.senate.gov//filings/public/filing/...
# 87   https://lda.senate.gov//filings/public/filing/...
# 88   https://lda.senate.gov//filings/public/filing/...
# 89   https://lda.senate.gov//filings/public/filing/...
# 90                                                   0
# 91   https://lda.senate.gov//filings/public/filing/...
# 92   https://lda.senate.gov//filings/public/filing/...
# 93   https://lda.senate.gov//filings/public/filing/...
# 94   https://lda.senate.gov//filings/public/filing/...
# 95   https://lda.senate.gov//filings/public/filing/...
# 96   https://lda.senate.gov//filings/public/filing/...
# 97   https://lda.senate.gov//filings/public/filing/...
# 98   https://lda.senate.gov//filings/public/filing/...
# 99   https://lda.senate.gov//filings/public/filing/...
# 100                                                  0
# 101                                                  0
# 102                                                  0
# 103                                                  0
# 104                                                  0
# 105                                                  0
# 106  https://lda.senate.gov//filings/public/filing/...
# 107                                                  0
# 108                                                  0
# 109                                                  0
# 110                                                  0
# 111                                                  0
# 112                                                  0
# 113                                                  0
# 114                                                  0
# 115  https://lda.senate.gov//filings/public/filing/...
# 116  https://lda.senate.gov//filings/public/filing/...
# 117                                                  0
# 118                                                  0
# 119                                                  0
# 120                                                  0
# 121                                                  0
# 122                                                  0
# 123                                                  0
# 124                                                  0
# 125  https://lda.senate.gov//filings/public/filing/...
# 126                                                  0
# 127                                                  0
# 128                                                  0
# 129                                                  0
# 130                                                  0
# 131                                                  0
# 132                                                  0
# 133                                                  0
# 134                                                  0
# 135  https://lda.senate.gov//filings/public/filing/...
# 136  https://lda.senate.gov//filings/public/filing/...
# 137                                                  0
# 138                                                  0
# 139                                                  0
# 140                                                  0
# 141                                                  0
# 142                                                  0
# 143  https://lda.senate.gov//filings/public/filing/...
# 144                                                  0
# 145                                                  0
# 146  https://lda.senate.gov//filings/public/filing/...
# 147  https://lda.senate.gov//filings/public/filing/...

# %% [markdown]
# ## ※ Check Amendment carefully. If needed, update numbers manually on .csv files.

# %%
df_Bigtech.to_csv('bigtech_lobby.csv', index=False)

# %% [markdown]
# ### (2) API version (only Amazon)

# %%
amas = [] 
for page in range(1,5):
    url = 'https://lda.senate.gov/api/v1/filings/?filing_uuid=&page={}&registrant_id=&registrant_name=Amazon'.format(page)
    res = requests.get(url)
    data = res.json()
    amas.append(data)

# %%
# amas[0]

# %%
am_url1 = 'https://lda.senate.gov/api/v1/filings/?filing_uuid=&page=1&registrant_id=&registrant_name=Amazon'
am_url2 = 'https://lda.senate.gov/api/v1/filings/?filing_uuid=&page=2&registrant_id=&registrant_name=Amazon'
am_url3 = 'https://lda.senate.gov/api/v1/filings/?filing_uuid=&page=3&registrant_id=&registrant_name=Amazon'
am_url4 = 'https://lda.senate.gov/api/v1/filings/?filing_uuid=&page=4&registrant_id=&registrant_name=Amazon'

# %%
res1 = requests.get(am_url1)
data1 = res1.json()
res2 = requests.get(am_url2)
data2 = res2.json()
res3 = requests.get(am_url3)
data3 = res3.json()
res4 = requests.get(am_url4)
data4 = res4.json()

# %%
# data.keys()
# print(data['count'])
# print(data['next'])
# data1['results'][1].keys()

# %%
amalobbies1 = data1['results']
amalobbies2 = data2['results']
amalobbies3 = data3['results']
amalobbies4 = data4['results']

# %%
amazons = []
for amalobby in amalobbies1:
    amazon = {}
    amazon['year'] = amalobby['filing_year'] 
    amazon['season'] = amalobby['filing_period']
    amazon['expenses'] = amalobby['expenses']
    amazon['url'] = amalobby['filing_document_url']
    amazons.append(amazon)
for amalobby in amalobbies2:
    amazon = {}
    amazon['year'] = amalobby['filing_year'] 
    amazon['season'] = amalobby['filing_period']
    amazon['expenses'] = amalobby['expenses']
    amazon['url'] = amalobby['filing_document_url']
    amazons.append(amazon)
for amalobby in amalobbies3:
    amazon = {}
    amazon['year'] = amalobby['filing_year'] 
    amazon['season'] = amalobby['filing_period']
    amazon['expenses'] = amalobby['expenses']
    amazon['url'] = amalobby['filing_document_url']
    amazons.append(amazon)
for amalobby in amalobbies4:
    amazon = {}
    amazon['year'] = amalobby['filing_year'] 
    amazon['season'] = amalobby['filing_period']
    amazon['expenses'] = amalobby['expenses']
    amazon['url'] = amalobby['filing_document_url']
    amazons.append(amazon)

# %%
# pd.DataFrame(amazons)
